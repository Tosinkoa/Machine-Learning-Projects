# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = ["Mon", "Tue", "Wed", "Thur", "Fri"]
y = [200, 300, 240, 260, 210]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))


# 3. Plot data
ax.plot(x, y)


# 4. Customize plot
ax.set(title="Office Visitor",
      xlabel="Days of the week",
      ylabel="Visitor amount")


# 5. Save & show (you save the whole figure)
# Out:
# [Text(0.5, 1.0, 'Office Visitor'),
#  Text(0.5, 0, 'Days of the week'),
#  Text(0, 0.5, 'Visitor amount')]
